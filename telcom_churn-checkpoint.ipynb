# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Customer Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ","0")
df['TotalCharges'] = df['TotalCharges'].astype("float")

# %% [markdown]
# ## replacing blanks with 0 as tenure is 0 and no total charges are recored

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
def conv(value):
    if value == 1:
        return "Yes"
    else:
        return "No"
df["SeniorCitizen"]=df["SeniorCitizen"].apply(conv)

# %% [markdown]
# ## Converted o and 1 values of senior citizen to yes/no to make it easier to understand.

# %%
df.head(5)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
plt.figure(figsize  = (4,4))
ax = sns.countplot(x = 'Churn',data=df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
gb = df.groupby('Churn').agg({'Churn':'count'})
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.figure(figsize = (3,4))
plt.pie(gb['Churn'],labels =gb.index,autopct="%1.2f%%")
plt.title("Percentage of churned customers",fontsize = 10)
plt.show()

# %% [markdown]
# #### from the given pie chart we can conclude that 26.54% of our customers have churned out

# %%
plt.figure(figsize=(4,4))
sns.countplot(x ="gender",data = df,hue = 'Churn')
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x ="SeniorCitizen",data = df,hue = 'Churn')
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
# create table
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'])

# convert to percentage
pct = ct.div(ct.sum(axis=1), axis=0) * 100

# plot stacked bar
pct.plot(kind='bar', stacked=True, figsize=(4,4))

# add percentage labels
for i in range(len(pct)):
    cum = 0
    for j in range(len(pct.columns)):
        value = pct.iloc[i, j]
        plt.text(i, cum + value/2, f'{value:.1f}%', ha='center')
        cum += value

plt.title("Churn by SeniorCitizen (%)")
plt.ylabel("Percentage")
plt.show()

# %% [markdown]
# #### comoarative a greated percentage of people on senior citzen category have chured

# %%
plt.figure(figsize = (10,5))
sns.histplot(x = 'tenure',data= df,bins = 72,hue = "Churn")
plt.show()

# %% [markdown]
# #### people who have used our services for a long time have stayed and people who have used our service have churn

# %%
plt.figure(figsize=(4,4))
ax = sns.countplot(x ="Contract",data = df,hue = 'Churn')
ax.bar_label(ax.containers[0])

plt.title("count by customers by Contract")
plt.show()

# %% [markdown]
# #### people who have month to month contract are likly to churn then form those who have 1 or 2 years or contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
cols = ['PhoneService','MultipleLines','InternetService',
        'OnlineSecurity','OnlineBackup','DeviceProtection',
        'TechSupport','StreamingTV','StreamingMovies']

plt.figure(figsize=(12,10))

for i, col in enumerate(cols,1):
    plt.subplot(3,3,i)
    sns.countplot(x=col, data=df,hue = 'Churn')
    plt.title(col)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Customers without OnlineSecurity, TechSupport, and DeviceProtection have much higher churn compared to those who have these services.Fiber optic InternetService users show higher churn than DSL users.Customers with PhoneService and MultipleLines mostly stay, but some still churn.Having extra services like OnlineBackup, StreamingTV, and StreamingMovies slightly reduces churn, but the difference is not very large.

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(x ="PaymentMethod",data = df,hue = 'Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.xticks(rotation = 45)

plt.title("count by customers by PaymentMethod")
plt.show()

# %% [markdown]
# #### customer is likely to churn when he is using electronic check as a payment method.

# %%
#### Read this file and I have mentioned some  anlysis in this file based on that create a summary for me on I have created in this file .I have created some good charts over here. so based on that create an executive summary for me.

# %%
#add more details to it whenever needed  display data in terms of percentage as well.

# %%
## summary and recommendations.

# %%
## Linkdin 
help me create a linkedin post  from this end in which will also add my github profile or github 
repository link and create a conversational post . do not add a lot of emotions . make it  simle ,
small and justice conversational where you can mention that i have a first project 
so i m pretty excited about it and would like to know everyone's feedback on it.
